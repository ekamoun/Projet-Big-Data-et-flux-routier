# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import matplotlib.pyplot as plt1

name = "C:\\Users\\fa56892\\Desktop\\us"
k=0
r=0
a=0
b=0
c=0
d=0
e=0
g=0
h=0
j=0
l=0
m=0
n=0
p=0
q=0
o=0
s=0
t=0
u=0
v=0
w=0
x=0
y=0
z=0
z1=0
r1=0
r2=0
r3=0
r4=0
r5=0
r6=0
r7=0
r8=0
r9=0
r10=0
r11=0



L=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
L1=[]
L2=[]
K1=[]
K2=[]
for f in os.listdir(name): 
    k=0
    r=0
    j=0
    df = pd.read_csv(name+"\\"+f, sep = ";")
    for i in df.index :
        if df.get_value(i, 'dep')==450 :
            if df.get_value(i, 'an')==1 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r+=1    
                    j+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r+=1    
                    k+=1
            if df.get_value(i, 'an')==2 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r1+=1    
                    a+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r1+=1    
                    b+=1
            if df.get_value(i, 'an')==3 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r2+=1    
                    c+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r2+=1    
                    d+=1
            if df.get_value(i, 'an')==4 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r3+=1    
                    e+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r3+=1    
                    g+=1
            if df.get_value(i, 'an')==5 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r4+=1    
                    h+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r4+=1    
                    l+=1
            if df.get_value(i, 'an')==6 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r5+=1    
                    m+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r5+=1    
                    n+=1    
            if df.get_value(i, 'an')==7 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r6+=1    
                    o+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r6+=1    
                    p+=1
            if df.get_value(i, 'an')==8 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r7+=1    
                    q+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r7+=1    
                    s+=1    
            if df.get_value(i, 'an')==9 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r8+=1    
                    t+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r8+=1    
                    u+=1
            if df.get_value(i, 'an')==11 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r9+=1    
                    v+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r9+=1    
                    w+=1   
            if df.get_value(i, 'an')==12 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r10+=1    
                    x+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r10+=1    
                    y+=1  
            if df.get_value(i, 'an')==13 : 
                if df.get_value(i, 'sexe')==1 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r11+=1    
                    z+=1
                elif df.get_value(i, 'sexe')==2 and df.get_value(i, 'catu')!=3 and df.get_value(i, 'catu')!=4  : 
                    r11+=1    
                    z1+=1            
                    
                    
    K1=[j,a,c,e,h,m,o,q,t,v,x,z]  
    K2=[k,b,d,g,l,n,p,s,u,w,y,z1]  
    L1=[round(j*100/r,3), round(a*100/r1,3), round(c*100/r2,3), round(e*100/r3,3), round(h*100/r4,3), round(m*100/r5,3), 
        round(o*100/r6,3), round(q*100/r7,3), round(t*100/r8,3), round(v*100/r9,3), round(x*100/r10,3), round(z*100/r11,3)]
    L2=[round(k*100/r,3), round(b*100/r1,3), round(d*100/r2,3), round(g*100/r3,3), round(l*100/r4,3), round(n*100/r5,3), 
        round(p*100/r6,3), round(s*100/r7,3), round(u*100/r8,3), round(w*100/r9,3), round(y*100/r10,3), round(z1*100/r11,3)]
L3=[]
for i in range(len(L1)) : 
    L3.append([L1[i],L2[i]])
print(L3)

colors = ['blue', 'red']
Label = ['Homme', 'Femme']

y = zip(*L3)
groups = len(L3)
pos = np.arange(groups)
width = 0.3

fig, ax = plt.subplots()    
for idx, (serie, color, Label) in enumerate(zip(y, colors, Label)):
    ax.bar(pos + idx * width, serie, width, color=color, label=Label)

ax.set_xticks(pos + 0.4*width)
ax.set_xticklabels(L)

plt.xlabel("Année")
plt.ylabel("Pourcentage")
plt.title("Pourcentage des conducteurs ayant commis des accidents par sexe", fontweight = 'bold')
plt.figure(1, figsize=(15, 3))
plt.legend()
plt.show()
# Out:
# C:\Users\fa56892\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-823927880af5> in <module>()
#     146     K2=[k,b,d,g,l,n,p,s,u,w,y,z1]
#     147     L1=[round(j*100/r,3), round(a*100/r1,3), round(c*100/r2,3), round(e*100/r3,3), round(h*100/r4,3), round(m*100/r5,3),
# --> 148         round(o*100/r6,3), round(q*100/r7,3), round(t*100/r8,3), round(v*100/r9,3), round(x*100/r10,3), round(z*100/r11,3)]
#     149     L2=[round(k*100/r,3), round(b*100/r1,3), round(d*100/r2,3), round(g*100/r3,3), round(l*100/r4,3), round(n*100/r5,3),
# ...
