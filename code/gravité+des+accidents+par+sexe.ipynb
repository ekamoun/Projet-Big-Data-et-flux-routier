# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

   
L = ['Indemne', 'Blessé léger', 'Blessé hospitalisé', "Tué"]
          
L3  = [[71.91, 28.08], [68.08, 31.91], [76.99, 23.00], [85.56, 14.43]]
colors = ['blue', 'red']
Label = ['Homme', 'Femme']

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        k= int(height)
        ax.text(rect.get_x() + rect.get_width()/2., 0.6*height,
                '%s' % str(k)+"%",
                ha='center', va='bottom')
        
y = zip(*L3)
groups = len(L3)
pos = np.arange(groups)
width = 0.3

fig, ax = plt.subplots()    
for idx, (serie, color, Label) in enumerate(zip(y, colors, Label)):
    rec=ax.bar(pos + idx * width, serie, width, color=color, label=Label)
    autolabel(rec)

ax.set_xticks(pos + 0.4*width)
ax.set_xticklabels(L)



plt.xlabel("Gravité")
plt.ylabel("Pourcentage des accidents")
plt.title("Gravité des accidents par sexe", fontweight = 'bold')
plt.legend()
plt.show()
