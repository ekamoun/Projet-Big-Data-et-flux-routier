# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import matplotlib.pyplot as plt1

name = "C:\\Users\\fa56892\\Desktop\\carac"
k=0
r=0
L=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
L1=[]
L2=[]
K1=[]
K2=[]
for f in os.listdir(name): 
    df = pd.read_csv(name+"\\"+f, sep = "\t", encoding='latin-1')
    L1.append(df.shape)
print(L[1])    
for i in range(0,len(L1)):    
    L2.append(L1[i][0])
print(L2)    
x = np.array(L)
y = np.array(L2)
plt.plot(x, y)
plt.title("Évolution du nombre d'accidents par année", fontweight = 'bold')
plt.xlabel("Année")
plt.ylabel("Nombre d'accidents")
plt.show()
# Out:
# 2006
# [87026, 82993, 83850, 76767, 74409, 69379, 66974, 62250, 58397, 59854, 58654, 59432]
